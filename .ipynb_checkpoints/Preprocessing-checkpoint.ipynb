# %% [markdown]
# # Imports

# %% [markdown]
# ## Packages

# %%
import pandas as pd
import holidays
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet
from prophet.diagnostics import cross_validation, performance_metrics

# import sklearn
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.decomposition import PCA

# Prophet model for time series forecast
# !pip install yfinance prophet

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data

# %%
df = pd.read_csv('DK_2.csv')
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
# df['Timestamp'] = pd.to_datetime(df['Timestamp'], format = '%Y%m%d %H:%M:%S')
# df['Date'] = pd.to_datetime(df['Date'], format = '%Y %m %d')

# %%
df.head().T
# Out:
#                                     0                    1  \
# Timestamp         2018-01-01 00:00:00  2018-01-01 01:00:00
# Date                       2018-01-01           2018-01-01
# TTF                               NaN                  NaN
# CO2                               NaN                  NaN
# Day-ahead prices                26.33                26.43
# Forecasted Load                3422.0               3289.0
# Actual Load                    3421.0               3308.0
# Solar                             0.0                  0.0
# Wind Offshore                   783.0                893.0
# Wind Onshore                   1493.0               1481.0
# Wind Total                     2276.0               2374.0
#
#                                     2                    3  \
# Timestamp         2018-01-01 02:00:00  2018-01-01 03:00:00
# Date                       2018-01-01           2018-01-01
# TTF                               NaN                  NaN
# CO2                               NaN                  NaN
# Day-ahead prices                 26.1                 24.7
# Forecasted Load                3157.0               3025.0
# Actual Load                    3118.0               3018.0
# Solar                             0.0                  0.0
# Wind Offshore                   755.0                747.0
# Wind Onshore                   1430.0               1458.0
# Wind Total                     2185.0               2205.0
#
#                                     4
# Timestamp         2018-01-01 04:00:00
# Date                       2018-01-01
# TTF                               NaN
# CO2                               NaN
# Day-ahead prices                24.74
# Forecasted Load                2939.0
# Actual Load                    2916.0
# Solar                             0.0
# Wind Offshore                   886.0
# Wind Onshore                   1472.0
# Wind Total                     2358.0

# %% [markdown]
# # Pre-processing

# %%
# add year, quarter, month, day, date and hour columns
def get_dt_info(df, dt_col, yr = False, qt = False, mo = False, day = False, date = False, w = False, h = False):
    if yr:
        df['Year'] = df[dt_col].dt.year
    if qt:
        df['Quarter'] = df[dt_col].dt.quarter
    if mo:
        df['Month'] = df[dt_col].dt.month
    if day:
        df['Day'] = df[dt_col].dt.day
    if date:
        df['Date'] = df[dt_col].dt.date
        df['Date'] = pd.to_datetime(df['Date'], format = '%Y %m %d')
    if w:
        if df[dt_col].dtype == '<M8[ns]':
            df['Week'] = df[dt_col].dt.isocalendar().week
        else:
            print(dt_col,'is not a date!')
    if h:
        df['Hour'] = df[dt_col].dt.hour
        
    return df

# %%
df = get_dt_info(df, 'Timestamp', yr = True, qt = True, mo = True, day = True, date = True, h = True)
df = get_dt_info(df, 'Date', w = True)
df.head().T
# Out:
#                                     0                    1  \
# Timestamp         2018-01-01 00:00:00  2018-01-01 01:00:00
# Date              2018-01-01 00:00:00  2018-01-01 00:00:00
# TTF                               NaN                  NaN
# CO2                               NaN                  NaN
# Day-ahead prices                26.33                26.43
# Forecasted Load                3422.0               3289.0
# Actual Load                    3421.0               3308.0
# Solar                             0.0                  0.0
# Wind Offshore                   783.0                893.0
# Wind Onshore                   1493.0               1481.0
# Wind Total                     2276.0               2374.0
# Year                             2018                 2018
# Quarter                             1                    1
# Month                               1                    1
# Day                                 1                    1
# Hour                                0                    1
# Week                                1                    1
#
#                                     2                    3  \
# Timestamp         2018-01-01 02:00:00  2018-01-01 03:00:00
# Date              2018-01-01 00:00:00  2018-01-01 00:00:00
# TTF                               NaN                  NaN
# CO2                               NaN                  NaN
# Day-ahead prices                 26.1                 24.7
# Forecasted Load                3157.0               3025.0
# Actual Load                    3118.0               3018.0
# Solar                             0.0                  0.0
# Wind Offshore                   755.0                747.0
# Wind Onshore                   1430.0               1458.0
# Wind Total                     2185.0               2205.0
# Year                             2018                 2018
# Quarter                             1                    1
# Month                               1                    1
# Day                                 1                    1
# Hour                                2                    3
# Week                                1                    1
#
#                                     4
# Timestamp         2018-01-01 04:00:00
# Date              2018-01-01 00:00:00
# TTF                               NaN
# CO2                               NaN
# Day-ahead prices                24.74
# Forecasted Load                2939.0
# Actual Load                    2916.0
# Solar                             0.0
# Wind Offshore                   886.0
# Wind Onshore                   1472.0
# Wind Total                     2358.0
# Year                             2018
# Quarter                             1
# Month                               1
# Day                                 1
# Hour                                4
# Week                                1

# %% [markdown]
# ## Differentiate business and non-business days

# %%
# calendar of holidays in DK
dk_bus = pd.tseries.offsets.CustomBusinessDay(calendar = holidays.DK())

# range of business days, excluding weekends and holidays
dk_bus_days = pd.bdate_range(min(df['Date']), max(df['Date']), freq = dk_bus)
df['business'] = df['Date'].isin(dk_bus_days)

# %% [markdown]
# # Imputation

# %%
# check for NaN values
for col in df.columns:
    a = df[col].isna().sum()
    if a > 0:
        b = df[(df[col].isna()) & (df['business'] == True)]
        print(col, a, 'of which', len(b), 'in', len(b['Date'].unique()),'business days')
# Out:
# TTF 13512 of which 1008 in 42 business days
# CO2 12936 of which 432 in 18 business days
# Day-ahead prices 23 of which 0 in 0 business days
# Forecasted Load 26 of which 2 in 1 business days
# Actual Load 26 of which 2 in 1 business days
# Solar 456 of which 310 in 22 business days
# Wind Offshore 120 of which 72 in 5 business days
# Wind Onshore 168 of which 120 in 8 business days
# Wind Total 168 of which 120 in 8 business days

# %%
# in most cases, 'TTF' and 'CO2' NaN are in non-business days, where the price is the same as the last business day --> ffill
for col in ['TTF', 'CO2']:
    df[col].fillna(method = 'ffill', inplace = True)

# %%
# check for NaN values
for col in df.columns:
    a = df[col].isna().sum()
    if a > 0:
        b = df[(df[col].isna()) & (df['business'])]
        print(col, a, 'of which', len(b), 'in', len(b['Date'].unique()),'business days')
# Out:
# TTF 24 of which 24 in 1 business days
# CO2 24 of which 24 in 1 business days
# Day-ahead prices 23 of which 0 in 0 business days
# Forecasted Load 26 of which 2 in 1 business days
# Actual Load 26 of which 2 in 1 business days
# Solar 456 of which 310 in 22 business days
# Wind Offshore 120 of which 72 in 5 business days
# Wind Onshore 168 of which 120 in 8 business days
# Wind Total 168 of which 120 in 8 business days

# %%
idx_drop = []
for col in ['TTF', 'CO2', 'Day-ahead prices']:
    print(col, df[df[col].isna()]['Date'].unique())
    idx_drop.append(df[df[col].isna()]['Date'].unique()[0])

idx_drop = set(idx_drop)
# Out:
# TTF ['2018-01-01T00:00:00.000000000']
# CO2 ['2018-01-01T00:00:00.000000000']
# Day-ahead prices ['2022-12-31T00:00:00.000000000']

# %%
# some missing are in the 1st and last day of the whole dataset, all observations for those days are dropped
df.drop(df[df['Date'].isin(idx_drop)].index, inplace = True)

# %%
# check for NaN values
for col in df.columns:
    a = df[col].isna().sum()
    if a > 0:
        b = df[df[col].isna()]['Date'].unique()
        print(col, a, '\nbusiness days', len(b), b)
# Out:
# Forecasted Load 2
# business days 1 ['2020-09-09T00:00:00.000000000']
# Actual Load 2
# business days 1 ['2020-09-09T00:00:00.000000000']
# Solar 432
# business days 32 ['2020-03-01T00:00:00.000000000' '2020-03-02T00:00:00.000000000'
#  '2020-07-15T00:00:00.000000000' '2020-07-16T00:00:00.000000000'
#  '2020-08-03T00:00:00.000000000' '2020-08-04T00:00:00.000000000'
#  '2021-10-07T00:00:00.000000000' '2021-10-08T00:00:00.000000000'
#  '2021-10-13T00:00:00.000000000' '2021-10-14T00:00:00.000000000'
#  '2022-04-30T00:00:00.000000000' '2022-05-01T00:00:00.000000000'
#  '2022-07-29T00:00:00.000000000' '2022-07-30T00:00:00.000000000'
#  '2022-08-11T00:00:00.000000000' '2022-08-12T00:00:00.000000000'
#  '2022-08-13T00:00:00.000000000' '2022-08-14T00:00:00.000000000'
#  '2022-08-16T00:00:00.000000000' '2022-08-17T00:00:00.000000000'
#  '2022-08-24T00:00:00.000000000' '2022-08-25T00:00:00.000000000'
#  '2022-08-28T00:00:00.000000000' '2022-08-29T00:00:00.000000000'
#  '2022-08-31T00:00:00.000000000' '2022-09-01T00:00:00.000000000'
#  '2022-09-04T00:00:00.000000000' '2022-09-05T00:00:00.000000000'
#  '2022-10-09T00:00:00.000000000' '2022-10-10T00:00:00.000000000'
#  '2022-11-17T00:00:00.000000000' '2022-11-26T00:00:00.000000000']
# Wind Offshore 96
# business days 6 ['2020-03-01T00:00:00.000000000' '2020-03-02T00:00:00.000000000'
#  '2021-10-07T00:00:00.000000000' '2021-10-08T00:00:00.000000000'
#  '2021-10-13T00:00:00.000000000' '2021-10-14T00:00:00.000000000']
# Wind Onshore 144
# business days 9 ['2020-03-01T00:00:00.000000000' '2020-03-02T00:00:00.000000000'
#  '2021-01-15T00:00:00.000000000' '2021-06-29T00:00:00.000000000'
#  '2021-06-30T00:00:00.000000000' '2021-10-07T00:00:00.000000000'
#  '2021-10-08T00:00:00.000000000' '2021-10-13T00:00:00.000000000'
#  '2021-10-14T00:00:00.000000000']
# Wind Total 144
# business days 9 ['2020-03-01T00:00:00.000000000' '2020-03-02T00:00:00.000000000'
#  '2021-01-15T00:00:00.000000000' '2021-06-29T00:00:00.000000000'
#  '2021-06-30T00:00:00.000000000' '2021-10-07T00:00:00.000000000'
#  '2021-10-08T00:00:00.000000000' '2021-10-13T00:00:00.000000000'
#  '2021-10-14T00:00:00.000000000']

# %%
df_temp = df.copy()
df_temp[(df_temp['Hour'] == 17) & ('2020-09-03'< df_temp['Date']) & (df_temp['Date'] <'2020-09-15')]
# Out:
#                 Timestamp       Date     TTF    CO2  Day-ahead prices  \
# 23465 2020-09-04 17:00:00 2020-09-04  11.680  28.13             47.95
# 23489 2020-09-05 17:00:00 2020-09-05  11.680  28.13             37.29
# 23513 2020-09-06 17:00:00 2020-09-06  11.680  28.13             42.01
# 23537 2020-09-07 17:00:00 2020-09-07  11.680  27.81             56.12
# 23561 2020-09-08 17:00:00 2020-09-08  10.800  27.53             49.68
# 23585 2020-09-09 17:00:00 2020-09-09  10.735  27.94             46.65
# 23609 2020-09-10 17:00:00 2020-09-10  10.515  29.15             65.81
# 23633 2020-09-11 17:00:00 2020-09-11  10.495  28.99             56.76
# 23657 2020-09-12 17:00:00 2020-09-12  10.495  28.99             33.02
# 23681 2020-09-13 17:00:00 2020-09-13  10.495  28.99             30.34
# 23705 2020-09-14 17:00:00 2020-09-14  10.705  31.20             80.98
#
#        Forecasted Load  Actual Load  Solar  Wind Offshore  Wind Onshore  \
# 23465           4108.0       4151.0   90.0          924.0        1520.0
# 23489           3789.0       3807.0   88.0         1111.0        1877.0
# 23513           3837.0       3881.0  105.0          785.0        1499.0
# 23537           4312.0       4348.0   99.0          917.0        1518.0
# 23561           4300.0       4300.0  100.0          967.0        1506.0
# 23585              NaN          NaN   77.0         1204.0        2360.0
# 23609           4409.0       4263.0   95.0          398.0         865.0
# 23633           4116.0       4185.0   76.0          869.0        1508.0
# 23657           3949.0       3948.0   73.0         1241.0        2455.0
# 23681           4018.0       4125.0   61.0         1205.0        2274.0
# 23705           4356.0       4369.0   90.0          154.0         376.0
#
#        Wind Total  Year  Quarter  Month  Day  Hour  Week  business
# 23465      2444.0  2020        3      9    4    17    36      True
# 23489      2988.0  2020        3      9    5    17    36     False
# 23513      2284.0  2020        3      9    6    17    36     False
# 23537      2435.0  2020        3      9    7    17    37      True
# 23561      2473.0  2020        3      9    8    17    37      True
# 23585      3564.0  2020        3      9    9    17    37      True
# 23609      1263.0  2020        3      9   10    17    37      True
# 23633      2377.0  2020        3      9   11    17    37      True
# 23657      3696.0  2020        3      9   12    17    37     False
# 23681      3479.0  2020        3      9   13    17    37     False
# 23705       530.0  2020        3      9   14    17    38      True

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43776 entries, 24 to 43799
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Timestamp         43776 non-null  datetime64[ns]
#  1   Date              43776 non-null  datetime64[ns]
#  2   TTF               43776 non-null  float64
#  3   CO2               43776 non-null  float64
#  4   Day-ahead prices  43776 non-null  float64
#  5   Forecasted Load   43774 non-null  float64
#  6   Actual Load       43774 non-null  float64
#  7   Solar             43344 non-null  float64
#  8   Wind Offshore     43680 non-null  float64
#  9   Wind Onshore      43632 non-null  float64
#  10  Wind Total        43632 non-null  float64
#  11  Year              43776 non-null  int64
#  12  Quarter           43776 non-null  int64
#  13  Month             43776 non-null  int64
#  14  Day               43776 non-null  int64
#  15  Hour              43776 non-null  int64
#  16  Week              43776 non-null  UInt32
#  17  business          43776 non-null  bool
# dtypes: UInt32(1), bool(1), datetime64[ns](2), float64(9), int64(5)
# memory usage: 5.9 MB

# %%
for i in range(24):
    check = df_temp[df_temp['Hour'] == i].rolling(4, min_periods = 1, closed = 'left', axis = 'rows').mean()
    df_temp.fillna(value = check, inplace = True)

# %%
df_temp.iloc[23555:23565, :]
# Out:
#                 Timestamp       Date     TTF    CO2  Day-ahead prices  \
# 23579 2020-09-09 11:00:00 2020-09-09  10.735  27.94             29.82
# 23580 2020-09-09 12:00:00 2020-09-09  10.735  27.94             29.79
# 23581 2020-09-09 13:00:00 2020-09-09  10.735  27.94             29.21
# 23582 2020-09-09 14:00:00 2020-09-09  10.735  27.94             29.17
# 23583 2020-09-09 15:00:00 2020-09-09  10.735  27.94             30.41
# 23584 2020-09-09 16:00:00 2020-09-09  10.735  27.94             32.45
# 23585 2020-09-09 17:00:00 2020-09-09  10.735  27.94             46.65
# 23586 2020-09-09 18:00:00 2020-09-09  10.735  27.94             46.88
# 23587 2020-09-09 19:00:00 2020-09-09  10.735  27.94             32.68
# 23588 2020-09-09 20:00:00 2020-09-09  10.735  27.94             28.59
#
#        Forecasted Load  Actual Load  Solar  Wind Offshore  Wind Onshore  \
# 23579           4639.0       4625.0  146.0         1094.0        2150.0
# 23580           4641.0       4624.0  170.0         1020.0        2099.0
# 23581           4554.0       4549.0  171.0          973.0        2183.0
# 23582           4401.0       4390.0  196.0         1080.0        2064.0
# 23583           4386.0       4374.0  207.0         1178.0        2259.0
# 23584           4094.5       4123.0  157.0         1206.0        2286.0
# 23585           4059.5       4084.0   77.0         1204.0        2360.0
# 23586           4188.0       4184.0   12.0         1201.0        2181.0
# 23587           4060.0       4107.0    0.0         1227.0        2066.0
# 23588           3809.0       3890.0    0.0         1307.0        2179.0
#
#        Wind Total  Year  Quarter  Month  Day  Hour  Week  business
# 23579      3244.0  2020        3      9    9    11    37      True
# 23580      3119.0  2020        3      9    9    12    37      True
# 23581      3156.0  2020        3      9    9    13    37      True
# 23582      3144.0  2020        3      9    9    14    37      True
# 23583      3437.0  2020        3      9    9    15    37      True
# 23584      3492.0  2020        3      9    9    16    37      True
# 23585      3564.0  2020        3      9    9    17    37      True
# 23586      3382.0  2020        3      9    9    18    37      True
# 23587      3293.0  2020        3      9    9    19    37      True
# 23588      3486.0  2020        3      9    9    20    37      True

# %%
# check for NaN values
for col in df_temp.columns:
    a = df_temp[col].isna().sum()
    if a > 0:
        b = df_temp[df_temp[col].isna()]['Date'].unique()
        print(col, a, '\nbusiness days', len(b), b)

# %%
df_temp.to_csv('DK_2_filled.csv', index = False)

# %% [markdown]
# # Lagging

# %%
df_lag = pd.DataFrame(df_temp['Day-ahead prices'].copy())
df_lag['DAP-lag1'] = df_lag['Day-ahead prices'].shift(1)
df_lag['DAP-lag2'] = df_lag['Day-ahead prices'].shift(2)
df_lag['DAP-lag3'] = df_lag['Day-ahead prices'].shift(3)
df_lag['DAP-lag4'] = df_lag['Day-ahead prices'].shift(4)
df_lag['DAP-lag5'] = df_lag['Day-ahead prices'].shift(5)
df_lag['DAP-lag6'] = df_lag['Day-ahead prices'].shift(6)
df_lag['DAP-lag7'] = df_lag['Day-ahead prices'].shift(7)
df_lag['DAP-lag8'] = df_lag['Day-ahead prices'].shift(8)
df_lag['DAP-lag9'] = df_lag['Day-ahead prices'].shift(9)
df_lag['DAP-lag10'] = df_lag['Day-ahead prices'].shift(10)
df_lag['DAP-lag11'] = df_lag['Day-ahead prices'].shift(11)
df_lag['DAP-lag12'] = df_lag['Day-ahead prices'].shift(12)
df_lag['DAP-lag24'] = df_lag['Day-ahead prices'].shift(24) # 1 day
df_lag['DAP-lag48'] = df_lag['Day-ahead prices'].shift(24*2) # 2 days
df_lag['DAP-lag168'] = df_lag['Day-ahead prices'].shift(24*7) # 1 week
df_lag['DAP-lag720'] = df_lag['Day-ahead prices'].shift(24*30) # 1 month
df_lag['DAP-lag2160'] = df_lag['Day-ahead prices'].shift(24*30*3) # 3 months
df_lag['DAP-lag8760'] = df_lag['Day-ahead prices'].shift(24*365) # 1 year

# %%
df_lag.head()
# Out:
#     Day-ahead prices  DAP-lag1  DAP-lag2  DAP-lag3  DAP-lag4  DAP-lag5  \
# 24             18.12       NaN       NaN       NaN       NaN       NaN
# 25             14.99     18.12       NaN       NaN       NaN       NaN
# 26             17.79     14.99     18.12       NaN       NaN       NaN
# 27             24.51     17.79     14.99     18.12       NaN       NaN
# 28             17.82     24.51     17.79     14.99     18.12       NaN
#
#     DAP-lag6  DAP-lag7  DAP-lag8  DAP-lag9  DAP-lag10  DAP-lag11  DAP-lag12  \
# 24       NaN       NaN       NaN       NaN        NaN        NaN        NaN
# 25       NaN       NaN       NaN       NaN        NaN        NaN        NaN
# 26       NaN       NaN       NaN       NaN        NaN        NaN        NaN
# 27       NaN       NaN       NaN       NaN        NaN        NaN        NaN
# 28       NaN       NaN       NaN       NaN        NaN        NaN        NaN
#
#     DAP-lag24  DAP-lag48  DAP-lag168  DAP-lag720  DAP-lag2160  DAP-lag8760
# 24        NaN        NaN         NaN         NaN          NaN          NaN
# 25        NaN        NaN         NaN         NaN          NaN          NaN
# 26        NaN        NaN         NaN         NaN          NaN          NaN
# 27        NaN        NaN         NaN         NaN          NaN          NaN
# 28        NaN        NaN         NaN         NaN          NaN          NaN

# %%
plt.figure(figsize = (10,10))
matrix = df_lag.corr().round(2)
sns.heatmap(matrix, annot=True)
plt.title('Auto-correlation for specific lags')
plt.show()

# %% [markdown]
# # PCA

# %%
df_lag_nan = df_lag.dropna(how = 'any', axis = 'index')

# %%
pca = PCA()
pca.fit(df_lag_nan)
print(pca.explained_variance_ratio_.cumsum())
# Out:
# [0.79948116 0.85843313 0.89141573 0.92189294 0.94472828 0.96100183
#  0.97521434 0.98206876 0.98801296 0.99274197 0.99524047 0.99677243
#  0.99764407 0.99824617 0.998694   0.99907818 0.99940612 0.99971218
#  1.        ]

# %% [markdown]
# ## Log transform

# %% [markdown]
# $\log$ can't deal with negative values, thus, check how many there are:

# %%
df_temp[df_temp['Day-ahead prices'] < 0].describe()
# Out:
#               TTF        CO2  Day-ahead prices  Forecasted Load  Actual Load  \
# count  250.000000  250.00000        250.000000       250.000000    250.00000
# mean    18.467968   25.90908         -6.779240      3364.228000   3369.91600
# std     19.460230   11.88238          8.079543       422.847756    431.74731
# min      3.890000    8.20000        -48.290000      2234.000000   2148.00000
# 25%      9.325000   22.18250         -9.610000      3074.000000   3091.50000
# 50%     15.410000   24.31000         -4.925000      3323.500000   3336.00000
# 75%     19.170000   27.06000         -1.720000      3618.500000   3643.75000
# max    159.565000   85.38000         -0.010000      5051.000000   5053.00000
#
#              Solar  Wind Offshore  Wind Onshore   Wind Total         Year  \
# count   250.000000     250.000000    250.000000   250.000000   250.000000
# mean    163.588000     887.296000   2643.288000  3530.584000  2019.412000
# std     282.648295     316.740123    633.984003   752.560926     0.897484
# min       0.000000     400.000000    686.000000  1097.000000  2018.000000
# 25%       0.000000     582.500000   2317.750000  3104.000000  2019.000000
# 50%       0.000000     872.000000   2683.500000  3581.500000  2019.000000
# 75%     247.500000    1166.000000   3135.500000  4003.750000  2020.000000
# max    1297.000000    1501.000000   3777.000000  5163.000000  2022.000000
#
#           Quarter       Month        Day        Hour       Week
# count  250.000000  250.000000  250.00000  250.000000      250.0
# mean     1.904000    4.656000   13.26400    7.180000      18.16
# std      1.111633    3.495503    9.22163    5.999632  15.291229
# min      1.000000    1.000000    1.00000    0.000000        1.0
# 25%      1.000000    2.000000    5.00000    3.000000        7.0
# 50%      2.000000    4.000000   12.50000    5.000000       14.0
# 75%      2.000000    5.000000   22.75000   12.750000      21.75
# max      4.000000   12.000000   31.00000   23.000000       52.0

# %%
plt.plot(df_temp[df_temp['Day-ahead prices'] >= 0]['Day-ahead prices'], label = 'Positive', linewidth = 0, marker = 'o', ms = 0.5)
plt.plot(df_temp[df_temp['Day-ahead prices'] < 0]['Day-ahead prices'], label = 'Negative', linewidth = 0, marker = 'o', ms = 0.5)
plt.title('Day-ahead prices\Time-series')
plt.xlabel('Time')
plt.ylabel('Price\€/MWh')
plt.legend()
plt.show()

# %%
df_temp['Day-ahead prices'].plot.hist(bins = 100)
plt.xlabel('Price\n€/MWh')
plt.title('Day-ahead prices\nHistogram')
plt.show()

# %%
df_log = df_temp[df_temp['Day-ahead prices'] > 0].copy()
df_log['Day-ahead prices log'] = np.log(df_log['Day-ahead prices'])

# %%
df_log['Day-ahead prices log'].plot.hist(bins = 100)
plt.xlabel('Price\n€/MWh')
plt.title('log(Day-ahead prices)\nHistogram')
plt.show()
