# %% [markdown]
# # Imports

# %%
from helper import *

# %% [markdown]
# # Data

# %%
df = read_our_data('DK_2_filled.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43776 entries, 0 to 43775
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Timestamp         43776 non-null  datetime64[ns]
#  1   Date              43776 non-null  datetime64[ns]
#  2   TTF               43776 non-null  float64
#  3   CO2               43776 non-null  float64
#  4   Day-ahead prices  43776 non-null  float64
#  5   Forecasted Load   43774 non-null  float64
#  6   Actual Load       43774 non-null  float64
#  7   Solar             43344 non-null  float64
#  8   Wind Offshore     43680 non-null  float64
#  9   Wind Onshore      43632 non-null  float64
#  10  Wind Total        43632 non-null  float64
#  11  Year              43776 non-null  int64
#  12  Quarter           43776 non-null  int64
#  13  Month             43776 non-null  int64
#  14  Day               43776 non-null  int64
#  15  Hour              43776 non-null  int64
#  16  Week              43776 non-null  int64
#  17  business          43776 non-null  bool
# dtypes: bool(1), datetime64[ns](2), float64(9), int64(6)
# memory usage: 5.7 MB

# %%
# lagged columns to add
lags = [24, 25, 26, 27, 28, 48, 72, 168]
col_to_lag = 'Day-ahead prices'
df_lagged = lag_df(df, col_to_lag, lags)
df_lagged.dropna(how = 'any', axis = 'index', inplace = True)

# %%
df_lagged.columns
# Out:
# Index(['Timestamp', 'Date', 'TTF', 'CO2', 'Day-ahead prices',
#        'Forecasted Load', 'Actual Load', 'Solar', 'Wind Offshore',
#        'Wind Onshore', 'Wind Total', 'Year', 'Quarter', 'Month', 'Day', 'Hour',
#        'Week', 'business', 'Day-ahead prices-lag24', 'Day-ahead prices-lag25',
#        'Day-ahead prices-lag26', 'Day-ahead prices-lag27',
#        'Day-ahead prices-lag28', 'Day-ahead prices-lag48',
#        'Day-ahead prices-lag72', 'Day-ahead prices-lag168'],
#       dtype='object')

# %%
# setting up features and target
cols_std = ['TTF', 'CO2', 'Forecasted Load', 'Actual Load',
            'Solar', 'Wind Offshore', 'Wind Onshore', 'Wind Total',
             'Day', 'Hour', 'Week', 'Day-ahead prices-lag24', 'Day-ahead prices-lag25', 'Day-ahead prices-lag26',
            'Day-ahead prices-lag27', 'Day-ahead prices-lag28', 'Day-ahead prices-lag48', 'Day-ahead prices-lag72', 'Day-ahead prices-lag168']
features = cols_std + ['Quarter', 'Month', 'business']
target = 'Day-ahead prices'

# %%
# setting up splits
k_folds = 3
train_start = pd.to_datetime(['2018-01-01', '2021-01-01', '2021-07-01'], format = '%Y-%m-%d')

# %% [markdown]
# # Models

# %% [markdown]
# ## Split - Method = 0
# The approach is to train and test in consecutive/sequential blocks, devoting 85% to training and 15% to test.

# %%
k_folds = 3
split_method = 0

# %% [markdown]
# ### Baseline

# %%
lr_pred_0, lr_model_0 = run_model('lr', df_lagged, k_folds, split_method,
                                         train_start, features, target, cols_std)
# Out:
# Iteration  0
# Mean Absolute Error (MAE): 10.526844909438196
# Mean Squared Error (MSE): 246.92628313134082
# Root Mean Squared Error (RMSE): 15.713888224476488
# Mean Absolute Percentage Error (MAPE): 32.31
# Accuracy: 67.69
# Iteration  1
# Mean Absolute Error (MAE): 10.915284849879745
# Mean Squared Error (MSE): 174.84012630288137
# Root Mean Squared Error (RMSE): 13.22271251683562
# Mean Absolute Percentage Error (MAPE): 18.85
# Accuracy: 81.15
# Iteration  2
# Mean Absolute Error (MAE): 45.52672057732842
# Mean Squared Error (MSE): 3337.0326471232747
# Root Mean Squared Error (RMSE): 57.76705503246011
# Mean Absolute Percentage Error (MAPE): 36.33
# Accuracy: 63.67

# %%
lr_model_0
# Out:
# [{'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False},
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False},
#  {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}]

# %% [markdown]
# ### Moving average

# %%
df_ma_0 = run_model('ma', df_lagged, k_folds, split_method,
                                         train_start, features, target, cols_std, pred_window = 24*1)

df_ma_0.dropna(how = 'any', axis = 0, inplace = True)
df_ma_0.drop(df_ma_0[df_ma_0[target] == 0].index, inplace = True)

# %%
ytrue = np.array(df_ma_0[target]).ravel()
ypred = np.array(df_ma_0['pred']).ravel()

# %%
model_evaluation(ytrue, ypred)
# Out:
# Mean Absolute Error (MAE): 29.10882471318413
# Mean Squared Error (MSE): 3177.3469843394773
# Root Mean Squared Error (RMSE): 56.367960618949816
# Mean Absolute Percentage Error (MAPE): 428.24
# Accuracy: -328.24
# (29.10882471318413,
#  3177.3469843394773,
#  56.367960618949816,
#  4.282406895114899,
#  -3.2824068951148986)

# %% [markdown]
# ### Random Forest

# %%
rf_pred_0, rf_models_0 = run_model('rf', df_lagged, k_folds, split_method, train_start, features, target, cols_std)
# Out:
# Iteration  0
# Mean Absolute Error (MAE): 11.08918323765864
# Mean Squared Error (MSE): 269.3423370017878
# Root Mean Squared Error (RMSE): 16.411652476267825
# Mean Absolute Percentage Error (MAPE): 31.87
# Accuracy: 68.13
# Iteration  1
# Mean Absolute Error (MAE): 10.917136886407407
# Mean Squared Error (MSE): 200.7544676112128
# Root Mean Squared Error (RMSE): 14.168784973003605
# Mean Absolute Percentage Error (MAPE): 19.16
# Accuracy: 80.84
# Iteration  2
# Mean Absolute Error (MAE): 45.511329966381375
# Mean Squared Error (MSE): 3684.663308026239
# Root Mean Squared Error (RMSE): 60.70142756168292
# Mean Absolute Percentage Error (MAPE): 34.93
# Accuracy: 65.07

# %% [markdown]
# ### XGBoost

# %%
xgb_pred_0, xgb_models_0 = run_model('xgb', df_lagged, k_folds, split_method, train_start, features, target, cols_std,'short_term')
# Out:
# Iteration  0
# Mean Absolute Error (MAE): 11.75866384126378
# Mean Squared Error (MSE): 299.9886716140407
# Root Mean Squared Error (RMSE): 17.320181050267365
# Mean Absolute Percentage Error (MAPE): 34.01
# Accuracy: 65.99
# Iteration  1
# Mean Absolute Error (MAE): 11.08962992776837
# Mean Squared Error (MSE): 208.8662480987733
# Root Mean Squared Error (RMSE): 14.452205648231459
# Mean Absolute Percentage Error (MAPE): 20.21
# Accuracy: 79.79
# Iteration  2
# Mean Absolute Error (MAE): 52.75733823374725
# Mean Squared Error (MSE): 4893.260592683426
# Root Mean Squared Error (RMSE): 69.95184481258107
# Mean Absolute Percentage Error (MAPE): 57.89
# Accuracy: 42.11

# %% [markdown]
# ## Split - Method = 1
# The approach is to split the data in increasing blocks. The size of the train set increases, whereas the size of the test remains 3 months.

# %%
split_method = 1

# %%
lr_pred_1, lr_model_1 = run_model('lr', df_lagged, k_folds, split_method,
                                         train_start, features, target, cols_std)
# Out:
# Iteration  0
# Mean Absolute Error (MAE): 12.478284406995915
# Mean Squared Error (MSE): 322.6471719219761
# Root Mean Squared Error (RMSE): 17.962382133836705
# Mean Absolute Percentage Error (MAPE): 39.01
# Accuracy: 60.99
# Iteration  1
# Mean Absolute Error (MAE): 9.649793206138437
# Mean Squared Error (MSE): 177.68048468180518
# Root Mean Squared Error (RMSE): 13.329684342916947
# Mean Absolute Percentage Error (MAPE): 18.93
# Accuracy: 81.07
# Iteration  2
# Mean Absolute Error (MAE): 57.497111866211476
# Mean Squared Error (MSE): 5520.687513621354
# Root Mean Squared Error (RMSE): 74.30132915110842
# Mean Absolute Percentage Error (MAPE): 32.88
# Accuracy: 67.12

# %%
rf_pred_1, rf_models_1 = run_model('rf', df_lagged, k_folds, split_method, train_start, features, target, cols_std, 'short_term')
# Out:
# Iteration  0
# Mean Absolute Error (MAE): 12.949678273537957
# Mean Squared Error (MSE): 345.57656735538234
# Root Mean Squared Error (RMSE): 18.58968981331809
# Mean Absolute Percentage Error (MAPE): 38.34
# Accuracy: 61.66
# Iteration  1
# Mean Absolute Error (MAE): 10.92003913232326
# Mean Squared Error (MSE): 208.14283595555497
# Root Mean Squared Error (RMSE): 14.427156197794316
# Mean Absolute Percentage Error (MAPE): 22.77
# Accuracy: 77.23
# Iteration  2
# Mean Absolute Error (MAE): 47.12546925993355
# Mean Squared Error (MSE): 4147.506569407636
# Root Mean Squared Error (RMSE): 64.40113795118558
# Mean Absolute Percentage Error (MAPE): 36.93
# Accuracy: 63.07

# %%
xgb_pred_1, xgb_models_1 = run_model('xgb', df_lagged, k_folds, split_method, train_start, features, target, cols_std)
# Out:
# Iteration  0
# Mean Absolute Error (MAE): 14.520847127549366
# Mean Squared Error (MSE): 404.86658751090533
# Root Mean Squared Error (RMSE): 20.12129686453896
# Mean Absolute Percentage Error (MAPE): 41.44
# Accuracy: 58.56
# Iteration  1
# Mean Absolute Error (MAE): 11.092271169897112
# Mean Squared Error (MSE): 199.35758874636792
# Root Mean Squared Error (RMSE): 14.11940468810098
# Mean Absolute Percentage Error (MAPE): 48.89
# Accuracy: 51.11
# Iteration  2
# Mean Absolute Error (MAE): 52.20265526089387
# Mean Squared Error (MSE): 4745.490657417283
# Root Mean Squared Error (RMSE): 68.88752178310149
# Mean Absolute Percentage Error (MAPE): 126.53
# Accuracy: -26.53

# %% [markdown]
# #### NOTES FRANCISCO/FREDERIK 14/04<br>
# correlation between ytrue and ypred, RMSE can be hard to refrence.<br>
# use power transform instead of log (how?)
