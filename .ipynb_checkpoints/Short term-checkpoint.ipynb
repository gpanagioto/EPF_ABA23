# %% [markdown]
# # Imports

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as sns
# import warnings
# warnings.filterwarnings('ignore')

# from sklearn import metrics
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.model_selection import RandomizedSearchCV
# from sklearn.linear_model import LinearRegression

# import xgboost as xg
# # from xgboost import *

# %%
from helper import *

# %% [markdown]
# # Data

# %%
df = read_our_data('DK_2_filled.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43776 entries, 0 to 43775
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Timestamp         43776 non-null  datetime64[ns]
#  1   Date              43776 non-null  datetime64[ns]
#  2   TTF               43776 non-null  float64
#  3   CO2               43776 non-null  float64
#  4   Day-ahead prices  43776 non-null  float64
#  5   Forecasted Load   43774 non-null  float64
#  6   Actual Load       43774 non-null  float64
#  7   Solar             43344 non-null  float64
#  8   Wind Offshore     43680 non-null  float64
#  9   Wind Onshore      43632 non-null  float64
#  10  Wind Total        43632 non-null  float64
#  11  Year              43776 non-null  int64
#  12  Quarter           43776 non-null  int64
#  13  Month             43776 non-null  int64
#  14  Day               43776 non-null  int64
#  15  Hour              43776 non-null  int64
# ...

# %%
# lagged columns to add
lags = [24, 25, 26, 27, 28, 48, 72]
col_to_lag = 'Day-ahead prices'
df_lagged = lag_df(df, col_to_lag, lags)
df_lagged.dropna(how = 'any', axis = 'index', inplace = True)

# %%
df_lagged.columns
# Out:
# Index(['Timestamp', 'Date', 'TTF', 'CO2', 'Day-ahead prices',
#        'Forecasted Load', 'Actual Load', 'Solar', 'Wind Offshore',
#        'Wind Onshore', 'Wind Total', 'Year', 'Quarter', 'Month', 'Day', 'Hour',
#        'Week', 'business', 'Day-ahead prices-lag24', 'Day-ahead prices-lag25',
#        'Day-ahead prices-lag26', 'Day-ahead prices-lag27',
#        'Day-ahead prices-lag28', 'Day-ahead prices-lag48',
#        'Day-ahead prices-lag72'],
#       dtype='object')

# %%
# setting up features and target
cols_std = ['TTF', 'CO2', 'Forecasted Load', 'Actual Load',
            'Solar', 'Wind Offshore', 'Wind Onshore', 'Wind Total',
             'Day', 'Hour', 'Week', 'Day-ahead prices-lag24', 'Day-ahead prices-lag25', 'Day-ahead prices-lag26',
            'Day-ahead prices-lag27', 'Day-ahead prices-lag28', 'Day-ahead prices-lag48', 'Day-ahead prices-lag72']
features = cols_std + ['Quarter', 'Month', 'business']
target = ['Day-ahead prices']

# %%
# setting up splits
k_folds = 3
train_start = pd.to_datetime(['2018-01-01', '2021-01-01', '2021-07-01'], format = '%Y-%m-%d')

# %% [markdown]
# # Models

# %% [markdown]
# ## Definition

# %%
# # rolling mean as a baseline
# def build_baseline(x_train, y_train, x_test, y_test, timeframe):
#     if timeframe == 'short_term':
#         lr = LinearRegression()
#         lr.fit(x_train, y_train)
#         model_ = lr
#         ypred = model_.predict(x_test)
#     return ypred, model_

# %%
# def build_rft(x_train,y_train,x_test,y_test, random_search = False):
#     # perform randomized search cross validation
#     rf = RandomForestRegressor(random_state = 42, min_samples_split = 10)
#     if random_search:
#         rf_grid = {'max_depth': [None, 3, 5, 10],
#                    'min_samples_split': np.arange(2, 20, 2),
#                    'min_samples_leaf': np.arange(1, 20, 2)}
#         rf = RandomizedSearchCV(estimator = rf, param_distributions = rf_grid, n_iter = 30, cv = 3, random_state=42, n_jobs = -1)
#         rf.fit(x_train, y_train)
#         # the optimal parameters
#         rf.best_estimator_.get_params()
#         # evaluate the optimal model
#         model_ = rf.best_estimator_
#     else:
#         rf.fit(x_train, y_train)
#         model_ = rf
        
#     ypred = model_.predict(x_test)
    
#     return ypred, model_

# %%
# def build_xgb(x_train,y_train,x_test,y_test):
#     xgb = xg.XGBRegressor(seed = 42)
#     xgb.fit(x_train, y_train)
    
#     model_= xgb
#     ypred = model_.predict(x_test)

#     return ypred, model_

# %%
# def build_nn(x_train,y_train,x_test,y_test):
# #     xgb = xg.XGBRegressor(seed = 42)
# #     xgb.fit(x_train, y_train)
    
# #     model_= xgb
# #     ypred = model_.predict(x_test)

#     return ypred, model_

# %%
# def run_model(model_type, df, k_folds, split_method, timeframe): # argument timeframe is necessary to choose baseline
#     ypred = []
#     models = []
#     for k in range(k_folds):
#         # split in train and test set
#         train_set, test_set = split_timeseries(df, train_start, k, method = split_method)

#         # get features and target
#         X_train, y_train = get_feature_target(train_set, features, target)
#         X_test, y_test = get_feature_target(test_set, features, target)

#         # standardize
#         X_train_std, X_test_std = standardize(X_train, X_test, cols_std)

#         if model_type == 'baseline':
#             yhat, model_ = build_baseline(X_train_std, y_train, X_test_std, y_test, timeframe = timeframe)
#         elif model_type == 'rft':
#             yhat, model_ = build_rft(X_train_std, y_train, X_test_std, y_test, random_search = True)
#         elif model_type == 'xgb':
#             yhat, model_ = build_xgb(X_train_std, y_train, X_test_std, y_test)
#         elif model_type = 'nn':
#             yhat, model_ = build_nn(X_train_std, y_train, X_test_std, y_test)

#         print('Iteration ', k)
#         model_evaluation(yhat, y_test)
        
#         ypred.append(yhat)
#         models.append(model_)
        
#     return ypred, models

# %% [markdown]
# ## Running

# %% [markdown]
# ### Split - Method = 0
# The approach is to train and test in consecutive/sequential blocks, devoting 85% to training and 15% to test.

# %%
k_folds = 3
split_method = 0

# %%
base_pred_st, base_models_st = run_model('baseline', df_lagged, k_folds, split_method,
                                         train_start, features, target, cols_std, 'short_term')
# Out:
# Iteration  0
# Mean Absolute Error (MAE): 10.904720836554981
# Mean Squared Error (MSE): 255.3861101301931
# Root Mean Squared Error (RMSE): 15.980804426880178
# Mean Absolute Percentage Error (MAPE): 33.54
# Accuracy: 66.46
# Iteration  1
# Mean Absolute Error (MAE): 12.577797184876337
# Mean Squared Error (MSE): 219.39326185925043
# Root Mean Squared Error (RMSE): 14.811929714228677
# Mean Absolute Percentage Error (MAPE): 21.96
# Accuracy: 78.04
# Iteration  2
# Mean Absolute Error (MAE): 46.58378304975609
# Mean Squared Error (MSE): 3471.1203169387177
# Root Mean Squared Error (RMSE): 58.916214380582176
# Mean Absolute Percentage Error (MAPE): 33.12
# Accuracy: 66.88

# %%
rf_pred, rf_models = run_model('rft', df_lagged, k_folds, split_method, train_start, features, target, cols_std, 'short_term')
# Out:
# Iteration  0
# Mean Absolute Error (MAE): 11.559486283921986
# Mean Squared Error (MSE): 285.0627898534493
# Root Mean Squared Error (RMSE): 16.88380258867798
# Mean Absolute Percentage Error (MAPE): 32.51
# Accuracy: 67.49
# Iteration  1
# Mean Absolute Error (MAE): 11.786110099257115
# Mean Squared Error (MSE): 227.36176646902177
# Root Mean Squared Error (RMSE): 15.078520035766832
# Mean Absolute Percentage Error (MAPE): 20.68
# Accuracy: 79.32
# Iteration  2
# Mean Absolute Error (MAE): 47.640752688721385
# Mean Squared Error (MSE): 4048.481888194562
# Root Mean Squared Error (RMSE): 63.62768177605218
# Mean Absolute Percentage Error (MAPE): 36.83
# Accuracy: 63.17

# %%
xgb_pred, xgb_models = run_model('xgb', df_lagged, k_folds, split_method, train_start, features, target, cols_std,'short_term')
# Out:
# Iteration  0
# Mean Absolute Error (MAE): 12.14288946864896
# Mean Squared Error (MSE): 310.2397764917463
# Root Mean Squared Error (RMSE): 17.613624740289726
# Mean Absolute Percentage Error (MAPE): 34.19
# Accuracy: 65.81
# Iteration  1
# Mean Absolute Error (MAE): 11.72984522205677
# Mean Squared Error (MSE): 223.76419342546785
# Root Mean Squared Error (RMSE): 14.958749728017642
# Mean Absolute Percentage Error (MAPE): 21.54
# Accuracy: 78.46
# Iteration  2
# Mean Absolute Error (MAE): 60.43647361880846
# Mean Squared Error (MSE): 6501.957700464761
# Root Mean Squared Error (RMSE): 80.63471771181915
# Mean Absolute Percentage Error (MAPE): 146.67
# Accuracy: -46.67

# %% [markdown]
# ## Split - Method = 1
# The approach is to split the data in increasing blocks. The size of the train set increases, whereas the size of the test remains 3 months.

# %%
split_method = 1

# %%
base_pred_st, base_models_st = run_model('baseline', df_lagged, k_folds, split_method,
                                         train_start, features, target, cols_std, 'short_term')
# Out:
# Iteration  0
# Mean Absolute Error (MAE): 12.911005946252859
# Mean Squared Error (MSE): 327.7719367674616
# Root Mean Squared Error (RMSE): 18.104472838706506
# Mean Absolute Percentage Error (MAPE): 38.61
# Accuracy: 61.39
# Iteration  1
# Mean Absolute Error (MAE): 10.261706060277014
# Mean Squared Error (MSE): 199.01529642137996
# Root Mean Squared Error (RMSE): 14.107278136528675
# Mean Absolute Percentage Error (MAPE): 19.56
# Accuracy: 80.44
# Iteration  2
# Mean Absolute Error (MAE): 58.3547632042964
# Mean Squared Error (MSE): 5617.761948495192
# Root Mean Squared Error (RMSE): 74.95173079052405
# Mean Absolute Percentage Error (MAPE): 33.2
# Accuracy: 66.8

# %%
rf_pred, rf_models = run_model('rft', df_lagged, k_folds, split_method, train_start, features, target, cols_std, 'short_term')
# Out:
# Iteration  0
# Mean Absolute Error (MAE): 13.822474372563189
# Mean Squared Error (MSE): 374.491783916143
# Root Mean Squared Error (RMSE): 19.351790199259163
# Mean Absolute Percentage Error (MAPE): 38.99
# Accuracy: 61.01
# Iteration  1
# Mean Absolute Error (MAE): 11.377792577739704
# Mean Squared Error (MSE): 220.17542207203672
# Root Mean Squared Error (RMSE): 14.838309272691303
# Mean Absolute Percentage Error (MAPE): 23.45
# Accuracy: 76.55
# Iteration  2
# Mean Absolute Error (MAE): 49.935986467394024
# Mean Squared Error (MSE): 4615.495732984574
# Root Mean Squared Error (RMSE): 67.93743984714595
# Mean Absolute Percentage Error (MAPE): 38.38
# Accuracy: 61.62

# %%
xgb_pred, xgb_models = run_model('xgb', df_lagged, k_folds, split_method, train_start, features, target, cols_std, 'short_term')
# Out:
# Iteration  0
# Mean Absolute Error (MAE): 14.390164261749089
# Mean Squared Error (MSE): 409.300281279536
# Root Mean Squared Error (RMSE): 20.231171030850785
# Mean Absolute Percentage Error (MAPE): 40.42
# Accuracy: 59.58
# Iteration  1
# Mean Absolute Error (MAE): 10.805577538195669
# Mean Squared Error (MSE): 193.9824376812649
# Root Mean Squared Error (RMSE): 13.927757812414205
# Mean Absolute Percentage Error (MAPE): 24.01
# Accuracy: 75.99
# Iteration  2
# Mean Absolute Error (MAE): 59.20779744588962
# Mean Squared Error (MSE): 6246.200609771673
# Root Mean Squared Error (RMSE): 79.0329083975256
# Mean Absolute Percentage Error (MAPE): 71.27
# Accuracy: 28.73

# %% [markdown]
# NOTES FRANCISCO/FREDERIK 14/04<br>
# correlation between ytrue and ypred, RMSE can be hard to refrence.<br>
# use power transform instead of log (how?)
