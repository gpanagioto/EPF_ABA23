# %% [markdown]
# # Further Stats regarding some interesting values

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
from analysis import *
from __init__ import root_dir, data_path

# %%
df = pd.read_csv(os.path.join(data_path, 'clean','clean.csv'), parse_dates= ['Timestamp', 'Date'])
df.head()
# Out:
#             Timestamp  DK_1_imports  SE_4_imports  DK_1_exports  SE_4_exports  \
# 0 2018-01-02 00:00:00         383.0           0.0           0.0         808.0
# 1 2018-01-02 01:00:00         589.0           0.0           0.0        1019.0
# 2 2018-01-02 02:00:00         557.0           0.0           0.0         926.0
# 3 2018-01-02 03:00:00         487.0           0.0           0.0         784.0
# 4 2018-01-02 04:00:00         580.0           0.0           0.0         756.0
#
#    Day_Ahead_price  Forecasted_Load  Actual_Load  Solar_[MW]  ttf_price  ...  \
# 0            18.12           1258.0       1245.0         0.0      19.32  ...
# 1            14.99           1188.0       1203.0         0.0      19.32  ...
# 2            17.79           1167.0       1178.0         0.0      19.32  ...
# 3            24.51           1187.0       1180.0         0.0      19.32  ...
# 4            17.82           1235.0       1247.0         0.0      19.32  ...
#
#    Year  Quarter  Month       Date  Day  Weekday  Hour  Week  business  \
# 0  2018        1      1 2018-01-02    2        1     0     1      True
# 1  2018        1      1 2018-01-02    2        1     1     1      True
# 2  2018        1      1 2018-01-02    2        1     2     1      True
# 3  2018        1      1 2018-01-02    2        1     3     1      True
# 4  2018        1      1 2018-01-02    2        1     4     1      True
#
#   Wind Total
# 0      429.0
# 1      375.0
# 2      313.0
# 3      229.0
# 4      175.0
#
# [5 rows x 26 columns]

# %%
df.columns.to_list()
# Out:
# ['Timestamp',
#  'DK_1_imports',
#  'SE_4_imports',
#  'DK_1_exports',
#  'SE_4_exports',
#  'Day_Ahead_price',
#  'Forecasted_Load',
#  'Actual_Load',
#  'Solar_[MW]',
#  'ttf_price',
#  'coal_price',
#  'co2_price',
#  'Biomass_Actual_Aggregated_[MW]',
#  'Waste_Actual_Aggregated_[MW]',
#  'DE_LU_AT_imports',
#  'DE_LU_AT_exports',
#  'Year',
#  'Quarter',
#  'Month',
#  'Date',
#  'Day',
#  'Weekday',
#  'Hour',
#  'Week',
#  'business',
#  'Wind Total']

# %%
split_dataset(df, 2018, 'Day_Ahead_price')
# Out:
#       Day_Ahead_price
# Hour
# 0           36.763846
# 1           35.326319
# 2           34.660742
# 3           34.621731
# 4           36.922005
# 5           41.988379
# 6           48.907473
# 7           54.669396
# 8           55.464478
# 9           53.961923
# 10          52.221868
# 11          49.920989
# 12          48.282198
# 13          47.097637
# 14          46.646401
# 15          47.510330
# 16          50.145467
# 17          54.249670
# 18          55.587335
# 19          52.241923
# 20          48.423929
# 21          44.957830
# 22          41.171813
# 23          38.571319

# %%
years = [2018, 2019, 2020, 2021, 2022]
attributes = ['Day_Ahead_price', 'Forecasted_Load', 'Biomass_Actual_Aggregated_[MW]', 'Waste_Actual_Aggregated_[MW]', 'Actual_Load', 'ttf_price', 'Solar_[MW]', 'Wind Total']

# %%
# Iteration yearly for some specific attributes and calculation of the summary statistics
for year in years:
    for attribute in attributes:
        # Create a new dataframe for the year and attribute
        df_year_attribute = split_dataset(df, year, attribute)
        
        # Calculate the summary statistics
        mean = df_year_attribute.mean()[0]
        median = df_year_attribute.median()[0]
        std = df_year_attribute.std()[0]
        minimum = df_year_attribute.min()[0]
        maximum = df_year_attribute.max()[0]
        
        # Print the summary statistics
        print(f"Hourly summary statistics for year {year} and attribute '{attribute}':")
        print(f"Mean: {mean:.2f}")
        print(f"Median: {median:.2f}")
        print(f"Standard deviation: {std:.2f}")
        print(f"Minimum: {minimum:.2f}")
        print(f"Maximum: {maximum:.2f}")
        print("\n")
# Out:
# Hourly summary statistics for year 2018 and attribute 'Day_Ahead_price':
# Mean: 46.26
# Median: 47.90
# Standard deviation: 7.09
# Minimum: 34.62
# Maximum: 55.59
#
#
# Hourly summary statistics for year 2018 and attribute 'Forecasted_Load':
# Mean: 1517.85
# Median: 1642.38
# Standard deviation: 247.59
# Minimum: 1113.33
# Maximum: 1801.07
#
#
# Hourly summary statistics for year 2018 and attribute 'Biomass_Actual_Aggregated_[MW]':
# Mean: 248.59
# Median: 257.19
# Standard deviation: 15.78
# Minimum: 221.90
# Maximum: 265.74
#
#
# Hourly summary statistics for year 2018 and attribute 'Waste_Actual_Aggregated_[MW]':
# Mean: 50.62
# Median: 51.10
# Standard deviation: 1.19
# Minimum: 48.47
# Maximum: 51.95
#
#
# Hourly summary statistics for year 2018 and attribute 'Actual_Load':
# Mean: 1518.77
# Median: 1642.18
# Standard deviation: 244.92
# Minimum: 1126.78
# Maximum: 1808.59
#
#
# Hourly summary statistics for year 2018 and attribute 'ttf_price':
# Mean: 22.26
# Median: 22.26
# Standard deviation: 0.00
# Minimum: 22.26
# Maximum: 22.28
#
#
# Hourly summary statistics for year 2018 and attribute 'Solar_[MW]':
# Mean: 40.08
# Median: 15.35
# Standard deviation: 47.34
# Minimum: 0.00
# Maximum: 126.10
#
#
# Hourly summary statistics for year 2018 and attribute 'Wind Total':
# Mean: 326.75
# Median: 331.72
# Standard deviation: 16.49
# Minimum: 302.40
# Maximum: 350.54
#
#
# Hourly summary statistics for year 2019 and attribute 'Day_Ahead_price':
# Mean: 39.84
# Median: 40.39
# Standard deviation: 5.66
# Minimum: 30.39
# Maximum: 49.17
#
#
# Hourly summary statistics for year 2019 and attribute 'Forecasted_Load':
# Mean: 1503.36
# Median: 1625.50
# Standard deviation: 243.67
# Minimum: 1108.64
# Maximum: 1778.04
#
#
# Hourly summary statistics for year 2019 and attribute 'Biomass_Actual_Aggregated_[MW]':
# Mean: 255.34
# Median: 263.52
# Standard deviation: 23.18
# Minimum: 213.84
# Maximum: 280.21
#
#
# Hourly summary statistics for year 2019 and attribute 'Waste_Actual_Aggregated_[MW]':
# Mean: 63.16
# Median: 63.48
# Standard deviation: 0.72
# Minimum: 61.89
# Maximum: 63.98
#
#
# Hourly summary statistics for year 2019 and attribute 'Actual_Load':
# Mean: 1503.25
# Median: 1622.85
# Standard deviation: 239.03
# Minimum: 1122.46
# Maximum: 1787.89
#
#
# Hourly summary statistics for year 2019 and attribute 'ttf_price':
# Mean: 14.65
# Median: 14.65
# Standard deviation: 0.00
# Minimum: 14.65
# Maximum: 14.65
#
#
# Hourly summary statistics for year 2019 and attribute 'Solar_[MW]':
# Mean: 40.53
# Median: 14.25
# Standard deviation: 48.07
# Minimum: 0.00
# Maximum: 127.45
#
#
# Hourly summary statistics for year 2019 and attribute 'Wind Total':
# Mean: 366.55
# Median: 370.30
# Standard deviation: 16.36
# Minimum: 342.07
# Maximum: 385.52
#
#
# Hourly summary statistics for year 2020 and attribute 'Day_Ahead_price':
# Mean: 28.41
# Median: 29.21
# Standard deviation: 7.53
# Minimum: 16.69
# Maximum: 41.55
#
#
# Hourly summary statistics for year 2020 and attribute 'Forecasted_Load':
# Mean: 1470.70
# Median: 1585.75
# Standard deviation: 231.91
# Minimum: 1098.23
# Maximum: 1739.20
#
#
# Hourly summary statistics for year 2020 and attribute 'Biomass_Actual_Aggregated_[MW]':
# Mean: 201.60
# Median: 207.45
# Standard deviation: 23.76
# Minimum: 160.33
# Maximum: 229.72
#
#
# Hourly summary statistics for year 2020 and attribute 'Waste_Actual_Aggregated_[MW]':
# Mean: 60.31
# Median: 60.49
# Standard deviation: 1.55
# Minimum: 57.81
# Maximum: 62.52
#
#
# Hourly summary statistics for year 2020 and attribute 'Actual_Load':
# Mean: 1470.28
# Median: 1582.68
# Standard deviation: 229.09
# Minimum: 1108.53
# Maximum: 1763.20
#
#
# Hourly summary statistics for year 2020 and attribute 'ttf_price':
# Mean: 9.61
# Median: 9.61
# Standard deviation: 0.00
# Minimum: 9.61
# Maximum: 9.63
#
#
# Hourly summary statistics for year 2020 and attribute 'Solar_[MW]':
# Mean: 44.33
# Median: 15.88
# Standard deviation: 52.58
# Minimum: 0.00
# Maximum: 140.04
#
#
# Hourly summary statistics for year 2020 and attribute 'Wind Total':
# Mean: 368.81
# Median: 373.19
# Standard deviation: 11.41
# Minimum: 351.96
# Maximum: 383.72
#
#
# Hourly summary statistics for year 2021 and attribute 'Day_Ahead_price':
# Mean: 87.91
# Median: 88.66
# Standard deviation: 18.14
# Minimum: 60.68
# Maximum: 118.88
#
#
# Hourly summary statistics for year 2021 and attribute 'Forecasted_Load':
# Mean: 1566.36
# Median: 1678.74
# Standard deviation: 230.32
# Minimum: 1196.37
# Maximum: 1829.04
#
#
# Hourly summary statistics for year 2021 and attribute 'Biomass_Actual_Aggregated_[MW]':
# Mean: 354.77
# Median: 357.27
# Standard deviation: 28.57
# Minimum: 308.02
# Maximum: 395.47
#
#
# Hourly summary statistics for year 2021 and attribute 'Waste_Actual_Aggregated_[MW]':
# Mean: 60.94
# Median: 61.14
# Standard deviation: 1.11
# Minimum: 59.16
# Maximum: 62.72
#
#
# Hourly summary statistics for year 2021 and attribute 'Actual_Load':
# Mean: 1567.05
# Median: 1679.67
# Standard deviation: 226.92
# Minimum: 1205.92
# Maximum: 1853.47
#
#
# Hourly summary statistics for year 2021 and attribute 'ttf_price':
# Mean: 47.08
# Median: 47.08
# Standard deviation: 0.03
# Minimum: 47.08
# Maximum: 47.20
#
#
# Hourly summary statistics for year 2021 and attribute 'Solar_[MW]':
# Mean: 49.29
# Median: 17.85
# Standard deviation: 58.55
# Minimum: 0.00
# Maximum: 156.42
#
#
# Hourly summary statistics for year 2021 and attribute 'Wind Total':
# Mean: 318.09
# Median: 323.06
# Standard deviation: 10.02
# Minimum: 299.59
# Maximum: 331.87
#
#
# Hourly summary statistics for year 2022 and attribute 'Day_Ahead_price':
# Mean: 210.15
# Median: 202.73
# Standard deviation: 38.60
# Minimum: 162.21
# Maximum: 288.08
#
#
# Hourly summary statistics for year 2022 and attribute 'Forecasted_Load':
# Mean: 1494.47
# Median: 1593.61
# Standard deviation: 212.88
# Minimum: 1160.62
# Maximum: 1750.45
#
#
# Hourly summary statistics for year 2022 and attribute 'Biomass_Actual_Aggregated_[MW]':
# Mean: 268.74
# Median: 268.91
# Standard deviation: 16.81
# Minimum: 239.82
# Maximum: 294.87
#
#
# Hourly summary statistics for year 2022 and attribute 'Waste_Actual_Aggregated_[MW]':
# Mean: 62.36
# Median: 62.26
# Standard deviation: 0.75
# Minimum: 61.46
# Maximum: 63.75
#
#
# Hourly summary statistics for year 2022 and attribute 'Actual_Load':
# Mean: 1493.96
# Median: 1589.38
# Standard deviation: 208.74
# Minimum: 1158.05
# Maximum: 1744.25
#
#
# Hourly summary statistics for year 2022 and attribute 'ttf_price':
# Mean: 132.11
# Median: 132.10
# Standard deviation: 0.01
# Minimum: 132.10
# Maximum: 132.17
#
#
# Hourly summary statistics for year 2022 and attribute 'Solar_[MW]':
# Mean: 68.12
# Median: 28.29
# Standard deviation: 78.65
# Minimum: 0.00
# Maximum: 208.52
#
#
# Hourly summary statistics for year 2022 and attribute 'Wind Total':
# Mean: 329.71
# Median: 330.23
# Standard deviation: 9.63
# Minimum: 314.30
# Maximum: 345.91

# %%
plot_hourly_data(df, 2018, 'Day_Ahead_price')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
attribute = 'Day_Ahead_price'

plot_hourly_data(df, 2019, 'Day_Ahead_price')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plot_hourly_data(df, 2022, 'Day_Ahead_price')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plot_hourly_data_all_years(df, years, 'Day_Ahead_price')

# %%
plot_load_difference(df, 2020)

# %%
compare_years(df, 2019, 2020, 'Day_Ahead_price')
# Out:
#       2019_Day_Ahead_price  2020_Day_Ahead_price  \
# Hour
# 0                32.511178             18.854754
# 1                31.279315             17.523743
# 2                30.394000             16.694809
# 3                30.478438             16.800492
# 4                31.983425             18.538852
# 5                36.852740             23.045710
# 6                42.584411             30.392158
# 7                46.046110             36.390000
# 8                45.466822             37.079071
# 9                43.951315             33.917377
# 10               42.737808             32.149672
# 11               41.290137             30.886393
# 12               40.071288             29.210874
# 13               39.346849             27.799071
# 14               39.338630             27.398552
# 15               40.286685             29.219098
# 16               43.179342             33.802186
# 17               47.084247             40.340246
# 18               49.172301             41.546776
# 19               46.976110             36.688087
# 20               43.368521             31.228579
# 21               40.497452             27.669945
# 22               37.052055             23.860383
# 23               34.092466             20.821995
#
#       2019_2020_Day_Ahead_price_diff
# Hour
# 0                         -13.656424
# 1                         -13.755572
# 2                         -13.699191
# 3                         -13.677947
# 4                         -13.444572
# 5                         -13.807029
# 6                         -12.192252
# 7                          -9.656110
# 8                          -8.387751
# 9                         -10.033938
# 10                        -10.588136
# 11                        -10.403744
# 12                        -10.860413
# 13                        -11.547778
# 14                        -11.940078
# 15                        -11.067587
# 16                         -9.377157
# 17                         -6.744001
# 18                         -7.625525
# 19                        -10.288022
# 20                        -12.139941
# 21                        -12.827507
# 22                        -13.191672
# 23                        -13.270471

# %%
df = df.set_index('Timestamp')

# %%
sns.set(rc={'figure.figsize':(14, 5)})

# %%
df['Day_Ahead_price'].plot(linewidth=0.7, color='#7dd87d');

# %%
cols_plot = ['Day_Ahead_price', 'Biomass_Actual_Aggregated_[MW]', 'Wind Total']
colors = ['#4f81c7', '#f05d23', '#7dd87d']


axes = df[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(14, 11), subplots=True, color=colors)
for ax in axes:
    ax.set_ylabel('Daily Totals')

# %%
df['diff'] = df['Biomass_Actual_Aggregated_[MW]'] - df['Actual_Load']
df['ratio'] = df['Biomass_Actual_Aggregated_[MW]']/df['Actual_Load']

# %%
cols_plot = ['ratio', 'diff']
ylabels=['ratio (0-1)', 'difference']
axes = df[cols_plot].plot(marker='.', alpha=0.5, linestyle='None', figsize=(14, 11), subplots=True)
for ax, ylab in zip(axes, ylabels):
    ax.set_ylabel(ylab)

# %%
ax = df.loc['2020', 'Day_Ahead_price'].plot()
ax.set_ylabel("Prediction of the next day's price (MW)");
