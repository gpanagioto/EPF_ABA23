# %%
from helper import *
from helper_mid import *
from time_analysis import *

# %%
df = pd.read_csv('../dataset_management/data/clean/clean_lagged.csv', parse_dates = ['Timestamp', 'Date'])

# %%
df['RES_weight'] = df[['Solar_[MW]', 'Biomass_Actual_Aggregated_[MW]', 'Waste_Actual_Aggregated_[MW]', 'Wind Total']].sum(axis = 1) / df['Actual_Load']

# %%
target = ['RES_weight']

# %%
plot_n_scat(df[target])

# %%
test_stationarity(df[target])
# Out:
# Results of dickey fuller test
# Test Statistics               -1.480849e+01
# p-value                        2.047585e-27
# No. of lags used               5.600000e+01
# Number of observations used    4.625600e+04
# critical value (1%)           -3.430491e+00
# critical value (5%)           -2.861602e+00
# critical value (10%)          -2.566803e+00
# dtype: float64
